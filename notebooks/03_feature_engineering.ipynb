# %% [markdown]
# # 03 — Feature Engineering
# Build order-level and customer-level features; churn label (365-day inactivity).
#
# **Outputs:** `data/featured/superstore_orders.csv`, `superstore_customers.csv`, `model_ready.csv`

# %%
import os
import sys
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
sys.path.insert(0, '.')

from src.feature_engineering import run_feature_engineering_pipeline

orders, customers, model_ready = run_feature_engineering_pipeline(
    input_path='data/preprocessed/superstore_preprocessed.csv',
    orders_path='data/featured/superstore_orders.csv',
    customers_path='data/featured/superstore_customers.csv',
    model_ready_path='data/featured/model_ready.csv'
)
print('Customers columns:', customers.columns.tolist())
customers.head()
