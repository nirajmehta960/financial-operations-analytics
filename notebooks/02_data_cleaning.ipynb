# %% [markdown]
# # 02 — Data Cleaning
# Run cleaning pipeline: drop Row ID/Country, parse dates, drop duplicates, validate ranges.
#
# **Output:** `data/preprocessed/superstore_preprocessed.csv`

# %%
import os
import sys
sys.path.insert(0, '..')
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

from src.data_cleaning import run_cleaning_pipeline

df = run_cleaning_pipeline(
    data_path='data/raw/superstore.csv',
    save_path='data/preprocessed/superstore_preprocessed.csv'
)
df.head()
